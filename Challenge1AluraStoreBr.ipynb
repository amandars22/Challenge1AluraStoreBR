# %% [markdown]
# <a href="https://colab.research.google.com/github/amandars22/Challenge1AluraStoreBR/blob/main/Challenge1AluraStoreBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
# Faturamento total LOJA 1

fat_loja_1 = round(sum(loja['Preço']),2)
print(fat_loja_1)

#Primeiro maior faturamento
# Out:
# 1534509.12

# %%
# Faturamento total LOJA 2

fat_loja_2 = round(sum(loja2['Preço']),2)
print(fat_loja_2)

#Segundo maior faturamento
# Out:
# 1488459.06

# %%
# Faturamento total LOJA 3

fat_loja_3 = round(sum(loja3['Preço']),2)
print(fat_loja_3)

#Terceiro maior faturamento
# Out:
# 1464025.03

# %%
# Faturamento total LOJA 4

fat_loja_4 = round(sum(loja4['Preço']),2)
print(fat_loja_4)

#Quarto maior faturamento
# Out:
# 1384497.58

# %%
# Gráfico comparando o faturamento total de cada loja

import matplotlib.pyplot as plt

lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
faturamentos = [fat_loja_1,fat_loja_2,fat_loja_3,fat_loja_4]

plt.bar(lojas,faturamentos, color ='purple')
plt.title('Faturamento Total por Loja')
plt.xlabel('Lojas')
plt.ylabel('Faturamento total em milhões (R$)')

for i, valor in enumerate(faturamentos):
    plt.text(i, valor + 20000, f'R${valor:,.2f}', ha='center', fontsize=7.5, color='black')

# %% [markdown]
# # 2. Vendas por Categoria

# %%
# Vendas por categoria LOJA 1

categorias = loja['Categoria do Produto'].tolist()

lista_categorias = set(categorias)

# Iniciando contadores
brinquedos = 0
eletrodomesticos = 0
eletronicos = 0
esporte_e_lazer = 0
instrumentos_musicais = 0
livros = 0
moveis = 0
utilidades_domesticas = 0

# Contagem por categoria

for artigo in categorias:
  if artigo == 'brinquedos':
    brinquedos +=1
  elif artigo == 'eletrodomesticos':
    eletrodomesticos +=1
  elif artigo == 'eletronicos':
    eletronicos +=1
  elif artigo == 'esporte e lazer':
    esporte_e_lazer +=1
  elif artigo == 'instrumentos musicais':
    instrumentos_musicais +=1
  elif artigo == 'livros':
    livros += 1
  elif artigo == 'moveis':
    moveis +=1
  else:
    utilidades_domesticas +=1

print('Quantidade de produtos vendidos por categoria')
print(f'Brinquedos: {brinquedos}')
print(f'Eletrodomésticos {eletrodomesticos}')
print(f'Eletrônicos: {eletronicos}')
print(f'Esporte e Lazer: {esporte_e_lazer}')
print(f'Instrumento Musical: {instrumentos_musicais}')
print(f'Livros: {livros}')
print(f'Móveis: {moveis}')
print(f'Utilidades domésticas: {utilidades_domesticas}')




# Recurso visual gráfico
labels = [
    'Brinquedos', 'Eletrodomésticos', 'Eletrônicos', 'Esporte e Lazer',
    'Instrumentos Musicais', 'Livros', 'Móveis', 'Utilidades Domésticas'
]
valores = [
    brinquedos, eletrodomesticos, eletronicos, esporte_e_lazer,
    instrumentos_musicais, livros, moveis, utilidades_domesticas
]

plt.figure(figsize=(6.5,6.5))
plt.pie(valores, labels=labels, autopct='%1.1f%%', startangle=50)
plt.title('Distribuição de Produtos Vendidos por Categoria - Loja 1')
plt.axis('equal')
plt.show()
# Out:
# Quantidade de produtos vendidos por categoria
# Brinquedos: 324
# Eletrodomésticos 312
# Eletrônicos: 448
# Esporte e Lazer: 284
# Instrumento Musical: 182
# Livros: 173
# Móveis: 465
# Utilidades domésticas: 171

# %%
# Vendas por categoria LOJA 2

categorias2 = loja2['Categoria do Produto'].tolist()

lista_categorias2 = set(categorias2)

# Iniciando contadores
brinquedos2 = 0
eletrodomesticos2 = 0
eletronicos2 = 0
esporte_e_lazer2 = 0
instrumentos_musicais2 = 0
livros2 = 0
moveis2 = 0
utilidades_domesticas2 = 0

# Contagem por categoria

for artigo2 in categorias2:
  if artigo2 == 'brinquedos':
    brinquedos2 +=1
  elif artigo2 == 'eletrodomesticos':
    eletrodomesticos2 +=1
  elif artigo2 == 'eletronicos':
    eletronicos2 +=1
  elif artigo2 == 'esporte e lazer':
    esporte_e_lazer2 +=1
  elif artigo2 == 'instrumentos musicais':
    instrumentos_musicais2 +=1
  elif artigo2 == 'livros':
    livros2 += 1
  elif artigo2 == 'moveis':
    moveis2 +=1
  else:
    utilidades_domesticas2 +=1

print('Quantidade de produtos vendidos por categoria')
print(f'Brinquedos: {brinquedos2}')
print(f'Eletrodomésticos {eletrodomesticos2}')
print(f'Eletrônicos: {eletronicos2}')
print(f'Esporte e Lazer: {esporte_e_lazer2}')
print(f'Instrumento Musical: {instrumentos_musicais2}')
print(f'Livros: {livros2}')
print(f'Móveis: {moveis2}')
print(f'Utilidades domésticas: {utilidades_domesticas2}')




# Recurso visual gráfico
labels2 = [
    'Brinquedos', 'Eletrodomésticos', 'Eletrônicos', 'Esporte e Lazer',
    'Instrumentos Musicais', 'Livros', 'Móveis', 'Utilidades Domésticas'
]
valores2 = [
    brinquedos2, eletrodomesticos2, eletronicos2, esporte_e_lazer2,
    instrumentos_musicais2, livros2, moveis2, utilidades_domesticas2
]

plt.figure(figsize=(6.5,6.5))
plt.pie(valores2, labels=labels2, autopct='%1.1f%%', startangle=50)
plt.title('Distribuição de Produtos Vendidos por Categoria - Loja 2')
plt.axis('equal')
plt.show()
# Out:
# Quantidade de produtos vendidos por categoria
# Brinquedos: 313
# Eletrodomésticos 305
# Eletrônicos: 422
# Esporte e Lazer: 275
# Instrumento Musical: 224
# Livros: 197
# Móveis: 442
# Utilidades domésticas: 181

# %%
# Vendas por categoria LOJA 3

categorias3 = loja3['Categoria do Produto'].tolist()

lista_categorias3 = set(categorias3)

# Iniciando contadores
brinquedos3 = 0
eletrodomesticos3 = 0
eletronicos3 = 0
esporte_e_lazer3 = 0
instrumentos_musicais3 = 0
livros3 = 0
moveis3 = 0
utilidades_domesticas3 = 0

# Contagem por categoria

for artigo3 in categorias3:
  if artigo3 == 'brinquedos':
    brinquedos3 +=1
  elif artigo3 == 'eletrodomesticos':
    eletrodomesticos3 +=1
  elif artigo3 == 'eletronicos':
    eletronicos3 +=1
  elif artigo3 == 'esporte e lazer':
    esporte_e_lazer3 +=1
  elif artigo3 == 'instrumentos musicais':
    instrumentos_musicais3 +=1
  elif artigo3 == 'livros':
    livros3 += 1
  elif artigo3 == 'moveis':
    moveis3 +=1
  else:
    utilidades_domesticas3 +=1

print('Quantidade de produtos vendidos por categoria')
print(f'Brinquedos: {brinquedos3}')
print(f'Eletrodomésticos {eletrodomesticos3}')
print(f'Eletrônicos: {eletronicos3}')
print(f'Esporte e Lazer: {esporte_e_lazer3}')
print(f'Instrumento Musical: {instrumentos_musicais3}')
print(f'Livros: {livros3}')
print(f'Móveis: {moveis3}')
print(f'Utilidades domésticas: {utilidades_domesticas3}')




# Recurso visual gráfico
labels3 = [
    'Brinquedos', 'Eletrodomésticos', 'Eletrônicos', 'Esporte e Lazer',
    'Instrumentos Musicais', 'Livros', 'Móveis', 'Utilidades Domésticas'
]
valores3 = [
    brinquedos3, eletrodomesticos3, eletronicos3, esporte_e_lazer3,
    instrumentos_musicais3, livros3, moveis3, utilidades_domesticas3
]

plt.figure(figsize=(6.5,6.5))
plt.pie(valores3, labels=labels3, autopct='%1.1f%%', startangle=50)
plt.title('Distribuição de Produtos Vendidos por Categoria - Loja 3')
plt.axis('equal')
plt.show()
# Out:
# Quantidade de produtos vendidos por categoria
# Brinquedos: 315
# Eletrodomésticos 278
# Eletrônicos: 451
# Esporte e Lazer: 277
# Instrumento Musical: 177
# Livros: 185
# Móveis: 499
# Utilidades domésticas: 177

# %%
# Vendas por categoria LOJA 4

categorias4 = loja4['Categoria do Produto'].tolist()

lista_categorias4 = set(categorias4)

# Iniciando contadores
brinquedos4 = 0
eletrodomesticos4 = 0
eletronicos4 = 0
esporte_e_lazer4 = 0
instrumentos_musicais4 = 0
livros4 = 0
moveis4 = 0
utilidades_domesticas4 = 0

# Contagem por categoria

for artigo4 in categorias4:
  if artigo4 == 'brinquedos':
    brinquedos4 +=1
  elif artigo4 == 'eletrodomesticos':
    eletrodomesticos4 +=1
  elif artigo4 == 'eletronicos':
    eletronicos4 +=1
  elif artigo4 == 'esporte e lazer':
    esporte_e_lazer4 +=1
  elif artigo4 == 'instrumentos musicais':
    instrumentos_musicais4 +=1
  elif artigo4 == 'livros':
    livros4 += 1
  elif artigo4 == 'moveis':
    moveis4 +=1
  else:
    utilidades_domesticas4 +=1

print('Quantidade de produtos vendidos por categoria')
print(f'Brinquedos: {brinquedos4}')
print(f'Eletrodomésticos {eletrodomesticos4}')
print(f'Eletrônicos: {eletronicos4}')
print(f'Esporte e Lazer: {esporte_e_lazer4}')
print(f'Instrumento Musical: {instrumentos_musicais4}')
print(f'Livros: {livros4}')
print(f'Móveis: {moveis4}')
print(f'Utilidades domésticas: {utilidades_domesticas4}')




# Recurso visual gráfico
labels4 = [
    'Brinquedos', 'Eletrodomésticos', 'Eletrônicos', 'Esporte e Lazer',
    'Instrumentos Musicais', 'Livros', 'Móveis', 'Utilidades Domésticas'
]
valores4 = [
    brinquedos4, eletrodomesticos4, eletronicos4, esporte_e_lazer4,
    instrumentos_musicais4, livros4, moveis4, utilidades_domesticas4
]

plt.figure(figsize=(6.5,6.5))
plt.pie(valores4, labels=labels4, autopct='%1.1f%%', startangle=50)
plt.title('Distribuição de Produtos Vendidos por Categoria - Loja 4')
plt.axis('equal')
plt.show()
# Out:
# Quantidade de produtos vendidos por categoria
# Brinquedos: 338
# Eletrodomésticos 254
# Eletrônicos: 451
# Esporte e Lazer: 277
# Instrumento Musical: 170
# Livros: 187
# Móveis: 480
# Utilidades domésticas: 201

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
# Média de avaliação dos clientes LOJA 1

import statistics as st

media_avaliacao_loja1 = round(st.mean(loja['Avaliação da compra']),2)

print(media_avaliacao_loja1)
# Out:
# 3.98

# %%
# Média de avaliação dos clientes LOJA 2

import statistics as st

media_avaliacao_loja2 = round(st.mean(loja2['Avaliação da compra']),2)

print(media_avaliacao_loja2)
# Out:
# 4.04

# %%
# Média de avaliação dos clientes LOJA 3

import statistics as st

media_avaliacao_loja3 = round(st.mean(loja3['Avaliação da compra']),2)

print(media_avaliacao_loja3)
# Out:
# 4.05

# %%
# Média de avaliação dos clientes LOJA 4

import statistics as st

media_avaliacao_loja4 = round(st.mean(loja4['Avaliação da compra']),2)

print(media_avaliacao_loja4)
# Out:
# 4.0

# %%
# Recurso visual

lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
media_avaliacao = [media_avaliacao_loja1, media_avaliacao_loja2, media_avaliacao_loja3, media_avaliacao_loja4]


plt.barh(lojas, media_avaliacao, color='orange')
plt.title('Média de Avaliação por Loja')
plt.xlabel('Média de Avaliação')
plt.xlim(0, 6)
for i, valor in enumerate(media_avaliacao):
    plt.text(valor + 0.1, i, f'{valor:,.2f}', va='center', fontsize=8)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
# Produtos mais e menos vendidos na LOJA 1

from collections import Counter

produtos1 = loja['Produto'].tolist()

frequencia1 = Counter(produtos1)

prod_mais_vendido = frequencia1.most_common(1)[0]

print(f'Produto mais vendido: {prod_mais_vendido[0]} -> {prod_mais_vendido[1]} vendas')

prod_menos_vendido = frequencia1.most_common()[-1]

print(f'Produto menos vendido: {prod_menos_vendido[0]} -> {prod_menos_vendido[1]} vendas')

#Recurso visual
prod = [prod_mais_vendido[0], prod_menos_vendido[0]]
qtde_prod = [prod_mais_vendido[1], prod_menos_vendido[1]]
plt.barh(prod, qtde_prod, color='teal')
plt.title('Produto Mais e Menos Vendidos (Loja 1)')
plt.xlabel('Quantidade de produtos (em unidades)')
plt.ylabel('Produto')
plt.xlim(0,70)
for i, valor in enumerate(qtde_prod):
    plt.text(valor + 2, i, f'{valor}', va='center', fontsize=8)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# Produto mais vendido: Micro-ondas -> 60 vendas
# Produto menos vendido: Celular ABXY -> 33 vendas

# %%
# Produtos mais e menos vendidos na LOJA 2

from collections import Counter

produtos2 = loja2['Produto'].tolist()

frequencia2 = Counter(produtos2)

prod_mais_vendido2 = frequencia2.most_common(1)[0]

print(f'Produto mais vendido: {prod_mais_vendido2[0]} -> {prod_mais_vendido2[1]} vendas')

prod_menos_vendido2 = frequencia2.most_common()[-1]

print(f'Produto menos vendido: {prod_menos_vendido2[0]} -> {prod_menos_vendido2[1]} vendas')

#Recurso visual
prod2 = [prod_mais_vendido2[0], prod_menos_vendido2[0]]
qtde_prod2 = [prod_mais_vendido2[1], prod_menos_vendido2[1]]
plt.barh(prod2, qtde_prod2, color='teal')
plt.title('Produto Mais e Menos Vendidos (Loja 2)')
plt.xlabel('Quantidade de produtos (em unidades)')
plt.ylabel('Produto')
plt.xlim(0,70)
for i, valor in enumerate(qtde_prod2):
    plt.text(valor + 2, i, f'{valor}', va='center', fontsize=8)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# Produto mais vendido: Iniciando em programação -> 65 vendas
# Produto menos vendido: Jogo de tabuleiro -> 32 vendas

# %%
# Produtos mais e menos vendidos na LOJA 3

from collections import Counter

produtos3 = loja3['Produto'].tolist()

frequencia3 = Counter(produtos3)

prod_mais_vendido3 = frequencia3.most_common(1)[0]

print(f'Produto mais vendido: {prod_mais_vendido3[0]} -> {prod_mais_vendido3[1]} vendas')

prod_menos_vendido3 = frequencia3.most_common()[-1]

print(f'Produto menos vendido: {prod_menos_vendido3[0]} -> {prod_menos_vendido3[1]} vendas')

#Recurso visual
prod3 = [prod_mais_vendido3[0], prod_menos_vendido3[0]]
qtde_prod3 = [prod_mais_vendido3[1], prod_menos_vendido3[1]]
plt.barh(prod3, qtde_prod3, color='teal')
plt.title('Produto Mais e Menos Vendidos (Loja 3)')
plt.xlabel('Quantidade de produtos (em unidades)')
plt.ylabel('Produto')
plt.xlim(0,70)
for i, valor in enumerate(qtde_prod3):
    plt.text(valor + 2, i, f'{valor}', va='center', fontsize=8)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# Produto mais vendido: Kit banquetas -> 57 vendas
# Produto menos vendido: Blocos de montar -> 35 vendas

# %%
# Produtos mais e menos vendidos na LOJA 4

from collections import Counter

produtos4 = loja4['Produto'].tolist()

frequencia4 = Counter(produtos4)

prod_mais_vendido4 = frequencia4.most_common(1)[0]

print(f'Produto mais vendido: {prod_mais_vendido4[0]} -> {prod_mais_vendido4[1]} vendas')

prod_menos_vendido4 = frequencia4.most_common()[-1]

print(f'Produto menos vendido: {prod_menos_vendido4[0]} -> {prod_menos_vendido4[1]} vendas')



#Recurso visual
prod4 = [prod_mais_vendido4[0], prod_menos_vendido4[0]]
qtde_prod4 = [prod_mais_vendido4[1], prod_menos_vendido4[1]]
plt.barh(prod4, qtde_prod4, color='teal')
plt.title('Produto Mais e Menos Vendidos (Loja 4)')
plt.xlabel('Quantidade de produtos (em unidades)')
plt.ylabel('Produto')
plt.xlim(0,70)
for i, valor in enumerate(qtde_prod4):
    plt.text(valor + 2, i, f'{valor}', va='center', fontsize=8)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# Produto mais vendido: Cama box -> 62 vendas
# Produto menos vendido: Guitarra -> 33 vendas

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
# Frete médio LOJA 1

frete_medio_loja1 = round(st.mean(loja['Frete']),2)
print(f'O frete médio da loja 1 é R$ {frete_medio_loja1}')
# Out:
# O frete médio da loja 1 é R$ 34.69

# %%
# Frete médio LOJA 2

frete_medio_loja2 = round(st.mean(loja2['Frete']),2)
print(f'O frete médio da loja 2 é R$ {frete_medio_loja2}')
# Out:
# O frete médio da loja 2 é R$ 33.62

# %%
# Frete médio LOJA 3

frete_medio_loja3 = round(st.mean(loja3['Frete']),2)
print(f'O frete médio da loja 3 é R$ {frete_medio_loja3}')
# Out:
# O frete médio da loja 3 é R$ 33.07

# %%
# Frete médio LOJA 4

frete_medio_loja4 = round(st.mean(loja4['Frete']),2)
print(f'O frete médio da loja 4 é R$ {frete_medio_loja4}')
# Out:
# O frete médio da loja 4 é R$ 31.28

# %%
# Recuros visual

# Gráfico comparando o frete médio de cada loja
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
frete_medio = [frete_medio_loja1,frete_medio_loja2,frete_medio_loja3,frete_medio_loja4]

plt.bar(lojas,frete_medio, color ='maroon')
plt.title('Frete Médio por Loja')
plt.xlabel('Lojas')
plt.ylabel('Frete médio (em reais)')

for i, valor in enumerate(frete_medio):
    plt.text(i, valor + 0.6, f'R${valor:,.2f}', ha='center', fontsize=7.5, color='black')

# %% [markdown]
# #Relatório de Recomendação ao Cliente

# %% [markdown]
# **Recomendação: Venda da Loja 4**
#
# ---
#
# Com base nas análises realizadas, recomenda-se a **venda da Loja 4**. Esta conclusão é sustentada por evidências concretas obtidas a partir dos dados disponibilizados pelo cliente.
#
# Observa-se que a Loja 4 apresenta o **menor faturamento** entre todas as unidades avaliadas, o que indica um desempenho comercial significativamente abaixo da média. Além disso, a loja possui **uma das menores avaliações de satisfação por parte dos clientes**, fator que compromete tanto a imagem da marca quanto a fidelização de consumidores.
#
# Em relação ao portfólio de produtos, os dados mostram que os itens mais e menos vendidos da Loja 4 são, respectivamente, **Cama box** e **Guitarra**. Considerando que a guitarra possui um valor unitário elevado, é razoável inferir que o volume de vendas da loja está concentrado em produtos de **menor valor agregado**, o que limita o potencial de faturamento.
#
# Diante desses indicadores, a manutenção da Loja 4 no portfólio da empresa representa um custo de oportunidade relevante. Portanto, recomenda-se sua venda como uma medida estratégica para otimização da rede de lojas e alocação mais eficiente de recursos.
#
#
#
#
#
# ![produtomaisemenosvendido.png](data:image/png;base64,...)
#
#
# ![faturamentoporloja.png](data:image/png;base64,...)![avaliacao.png](data:image/png;base64,...)
